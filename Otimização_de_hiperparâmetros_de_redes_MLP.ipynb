# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelLemosS/IA/blob/Otimiza%C3%A7%C3%A3o/Otimiza%C3%A7%C3%A3o_de_hiperpar%C3%A2metros_de_redes_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
data = pd.read_excel("Rice Data.xlsx")
data
# Out:
#        Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0     15231  525.578979         229.749878          85.093788      0.928882
# 1     14656  494.311005         206.020065          91.730972      0.895405
# 2     14634  501.122009         214.106781          87.768288      0.912118
# 3     13176  458.342987         193.337387          87.448395      0.891861
# 4     14688  507.166992         211.743378          89.312454      0.906691
# ...     ...         ...                ...                ...           ...
# 3805  11441  415.858002         170.486771          85.756592      0.864280
# 3806  11625  421.390015         167.714798          89.462570      0.845850
# 3807  12437  442.498993         183.572922          86.801979      0.881144
# 3808   9882  392.296997         161.193985          78.210480      0.874406
# 3809  11434  404.709992         161.079269          90.868195      0.825692
#
#       Convex_Area    Extent     Class
# ...

# %%
le=LabelEncoder()
data["Class"]=le.fit_transform(data["Class"])
data["Class"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3805    1
# 3806    1
# 3807    1
# 3808    1
# 3809    1
# Name: Class, Length: 3810, dtype: int64

# %%
X=data.drop(["Class"], axis=1)
y=data["Class"]

# %%
sc=StandardScaler()
X=pd.DataFrame(sc.fit_transform(X))
X
# Out:
#              0         1         2         3         4         5         6
# 0     1.479830  2.004354  2.348547 -0.212943  2.018337  1.499659 -1.152921
# 1     1.147870  1.125853  0.988390  0.945568  0.410018  1.192918 -0.602079
# 2     1.135169  1.317214  1.451908  0.253887  1.212956  1.126504  0.405611
# 3     0.293436  0.115300  0.261439  0.198051  0.239751  0.233857 -0.275351
# 4     1.166345  1.487053  1.316442  0.523419  0.952221  1.299855 -0.206013
# ...        ...       ...       ...       ...       ...       ...       ...
# 3805 -0.708215 -1.078353 -1.048323 -0.097251 -1.085282 -0.745465  0.247031
# 3806 -0.601988 -0.922926 -1.207208  0.549622 -1.970731 -0.590124  0.418815
# 3807 -0.133204 -0.329851 -0.298245  0.085220 -0.275099 -0.173068 -0.455731
# 3808 -1.608257 -1.740320 -1.580971 -1.414414 -0.598821 -1.607156 -0.037168
# 3809 -0.712256 -1.391566 -1.587546  0.794972 -2.939160 -0.766290  1.825947
#
# [3810 rows x 7 columns]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=100)
X.shape
# Out:
# (3810, 7)

# %%
#Camada: 1, 5, 7, 10
#Neuronios: 25, 50, 100, 200, 500
neuronios = 500
model = keras.Sequential(
    [
        keras.Input(7),
        keras.layers.Dense(units=neuronios, activation='relu'),
        keras.layers.Dense(units=neuronios, activation='relu'),
        keras.layers.Dense(units=neuronios, activation='relu'),
        keras.layers.Dense(units=neuronios, activation='relu'),
        keras.layers.Dense(units=neuronios, activation='relu'),
        keras.layers.Dense(units=neuronios, activation='relu'),
        keras.layers.Dense(units=neuronios, activation='relu'),
        keras.layers.Dense(units=neuronios, activation='relu'),
        keras.layers.Dense(units=neuronios, activation='relu'),
        keras.layers.Dense(units=neuronios, activation='relu'),
        layers.Dense(1, activation = "softmax"),

    ]
)

# %%
model.summary()
# Out:
# Model: "sequential_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_182 (Dense)           (None, 500)               4000
#
#  dense_183 (Dense)           (None, 500)               250500
#
#  dense_184 (Dense)           (None, 500)               250500
#
#  dense_185 (Dense)           (None, 500)               250500
#
#  dense_186 (Dense)           (None, 500)               250500
#
#  dense_187 (Dense)           (None, 500)               250500
#
#  dense_188 (Dense)           (None, 500)               250500
#
#  dense_189 (Dense)           (None, 500)               250500
#
#  dense_190 (Dense)           (None, 500)               250500
#
#  dense_191 (Dense)           (None, 500)               250500
#
#  dense_192 (Dense)           (None, 1)                 501
#
# ...
# Total params: 2259001 (8.62 MB)
# Trainable params: 2259001 (8.62 MB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X,y, epochs=2,  batch_size = 128)
# Out:
# Epoch 1/2
# 30/30 [==============================] - 4s 51ms/step - loss: 0.2726 - accuracy: 0.5722
# Epoch 2/2
# 30/30 [==============================] - 1s 50ms/step - loss: 0.1894 - accuracy: 0.5722
